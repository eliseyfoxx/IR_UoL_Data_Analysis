# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction-to-pandas" data-toc-modified-id="Introduction-to-pandas-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction to pandas</a></span><ul class="toc-item"><li><span><a href="#Load-data-and-explore-it" data-toc-modified-id="Load-data-and-explore-it-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Load data and explore it</a></span></li><li><span><a href="#Main-characteristics" data-toc-modified-id="Main-characteristics-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Main characteristics</a></span><ul class="toc-item"><li><span><a href="#Aggregating-functions" data-toc-modified-id="Aggregating-functions-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Aggregating functions</a></span></li><li><span><a href="#Groupings" data-toc-modified-id="Groupings-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Groupings</a></span></li><li><span><a href="#Unique-values" data-toc-modified-id="Unique-values-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Unique values</a></span></li></ul></li><li><span><a href="#Distribution-histogram" data-toc-modified-id="Distribution-histogram-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Distribution histogram</a></span><ul class="toc-item"><li><span><a href="#Average,-Median,-Mode" data-toc-modified-id="Average,-Median,-Mode-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Average, Median, Mode</a></span></li></ul></li><li><span><a href="#Creating-and-deleting-columns" data-toc-modified-id="Creating-and-deleting-columns-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Creating and deleting columns</a></span></li><li><span><a href="#Indexing-and-slicing" data-toc-modified-id="Indexing-and-slicing-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Indexing and slicing</a></span><ul class="toc-item"><li><span><a href="#Indexing" data-toc-modified-id="Indexing-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Indexing</a></span></li><li><span><a href="#Conditional-slices" data-toc-modified-id="Conditional-slices-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Conditional slices</a></span></li><li><span><a href="#Conditional-operators" data-toc-modified-id="Conditional-operators-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Conditional operators</a></span></li><li><span><a href="#Working-with-strings" data-toc-modified-id="Working-with-strings-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>Working with strings</a></span></li></ul></li></ul></li><li><span><a href="#Review" data-toc-modified-id="Review-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Review</a></span></li><li><span><a href="#Practice" data-toc-modified-id="Practice-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Practice</a></span></li></ul></div>

# %% [markdown]
# # Introduction to pandas

# %% [markdown]
# - Pandas is a Python language library for convenient data processing and analysis.
# - Official documentation [here](https://pandas.pydata.org/docs/user_guide/index.html#user-guide )
# ---
# A small list of references:
# 1. [pandas Cheat Sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# 2. [Introduction to pandas](https://khashtamov.com/ru/pandas-introduction/ )
# 3. [Tutorials in official documentation (in English)](https://pandas.pydata.org/docs/getting_started/10min.html )
# 4. Good [article](http://habr.com/ru/company/tods/blog/322626) about how you can do different things in pandas

# %% [markdown]
# ## Load data and explore it

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Importing the pandas library

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# ! pip install pandas # installing the module if it is not there and the above error
# ! pip install --upgrade pandas # module update

# %% [markdown]
# - We will analyze the classic dataset about diamonds.
# - More information about it [here](https://www.kaggle.com/shivam2503/diamonds ).
# - You can download it [here](https://drive.google.com/file/d/1PwB6fLZiAOwpDu7VzyI1suOdRgs5YvdA/view )
#
# Description of dataset columns:
# - `price` – the price of the diamond (in dollars)
# - `carat` – the weight of the diamond (in carats)
# - `cut` – diamond cut quality (Fair, Good, Very Good, Premium, Ideal)
# - `color` – the color of the diamond, from J (worst) to D (best)
# - `clarity` - diamond purity (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
# - `x` `y` `z` – length, width, height (in mm)
# - `depth` - percentage of depth equal to 2 * z / (x + y)
# - `table` - width of the platform on top of the diamond

# %% [markdown]
# Loading the dataset from the 'csv' file into the `df' variable of the special type 'pd.dataframe'. Carefully specify the path to the file.
#
# If you don't want to specify the path to the file, move the dataset to the same folder as the notebook!

# %%
df = pd.read_csv('diamonds.csv')

## if you need to specify the path to the file
#df = pd.read_csv('~/Downloads/diamonds.csv')

# %%
df
# Out:
#        weight        cut color clarity  price      volume
# 14794    46.0      Ideal     E     SI2    326   38.202030
# 7150     42.0    Premium     E     SI1    326   34.505856
# 49714    46.0       Good     E     VS1    327   38.076885
# 1004     58.0    Premium     I     VS2    334   46.724580
# 15711    62.0       Good     J     SI2    335   51.917250
# ...       ...        ...   ...     ...    ...         ...
# 16264   144.0      Ideal     D     SI1   2757  115.920000
# 1655    144.0       Good     D     SI1   2757  118.110175
# 9869    140.0  Very Good     D     SI1   2757  114.449728
# 37761   172.0    Premium     H     SI2   2757  140.766120
# 31817   150.0      Ideal     D     SI2   2757  124.568444
#
# [53920 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
## if you are lost, where are you, check it ouhet!

# import os 
# os.getcwd()

# %% [markdown]
# the `read_csv` function has a number of important parameters that can sometimes come in handy
# - `sep` - data separator, by default `,`
# - `decimal` - separator of a number into integer and fractional parts, by default `."
# - `names` - a list with column names
# - `skiprows` — if the file contains system information, you can just skip it
# - `index_col` - the number of the column with the index

# %% [markdown]
# Let's look at the first rows of the dataset using the `.head()' method and the last 5 rows using the .tail() method

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.head(3)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %%
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
df.sample(5)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 6741    0.33    Premium     E     SI1   60.4   59.0    579  4.43  4.47  2.69
# 21843   1.50  Very Good     F     SI1   62.8   56.0   9904  7.26  7.33  4.58
# 29332   0.31    Premium     H     VS1   62.6   60.0    698  4.32  4.30  2.70
# 17636   1.29       Good     I     VS2   57.9   61.0   7102  7.16  7.13  4.14
# 34165   0.33      Ideal     G     VS1   61.4   54.0    854  4.48  4.44  2.74

# %% [markdown]
# Let's look at the size of our dataset using the `shape' attribute, which outputs a 'tuple` of two numbers
# - the first number is the number of rows (observations)
# - the second number is the number of columns

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.shape[0] # number of rows
# Out:
# 53940

# %%
df.shape[1] # number of columns
# Out:
# 10

# %% [markdown]
# Let's look at the information about the dataset.
#
# You can pass additional parameters to the `.info()' method, including:
#
# - `verbose`: whether to print the information about the `dataframe` completely (if the table is very large, some information may be lost)
# - `memory_usage`: whether to print memory consumption (by default `True` is used, but you can set either `False`, which will remove memory consumption, or 'deep', which will calculate memory consumption more accurately)
# - `null_counts`: whether to count the number of empty elements (by default 'True')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# You can only output the data type in each column

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %% [markdown]
# ## Main characteristics

# %% [markdown]
# ### Aggregating functions

# %% [markdown]
# The `.describe()` method shows the main statistical characteristics of the data for each numeric attribute (types `int64` and `float64`):
# - `count` – the number of missing values
# - `mean` `std` – mean, standard deviation
# - `min`, `max` – minimum, maximum
# - `25%`, `50%`, `75%` – quartiles of levels 0.25, 0.50, 0.75

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %% [markdown]
# To view statistics on non-numeric attributes (for example, on lowercase (`object`) or boolean (`bool`) data), you need to explicitly specify the types we are interested in in the `include` parameter of the `describe` method, then
# - `unique` – the number of unique categories in the column
# - `top` is the most frequently encountered category
# - `freq` – the number of occurrences of the most frequently encountered category in the dataset

# %%
df.describe(include = ['object'])
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# From the table we can "get" a separate column, which will already be of another special type `pd.Series`
#
# This can be done in several ways, for example
# ```python
# df['col']
# ```
#
# If the column name is in Latin without spaces, you can write
# ```python
# df.col
# ```

# %%
type(df.cut)
# Out:
# pandas.core.series.Series

# %%
df['color']
# Out:
# 0        E
# 1        E
# 2        E
# 3        I
# 4        J
#         ..
# 53935    D
# 53936    D
# 53937    D
# 53938    H
# 53939    D
# Name: color, Length: 53940, dtype: object

# %%
df.color
# Out:
# 0        E
# 1        E
# 2        E
# 3        I
# 4        J
#         ..
# 53935    D
# 53936    D
# 53937    D
# 53938    H
# 53939    D
# Name: color, Length: 53940, dtype: object

# %%
df['color'].describe()
# Out:
# count     53940
# unique        7
# top           G
# freq      11292
# Name: color, dtype: object

# %% [markdown]
# For a separate column, you can also calculate all the characteristics that are output from the `describe` method

# %%
df['carat'].mean()
# Out:
# 0.7979397478679852

# %%
import numpy as np

np.mean(df['carat'])
# Out:
# 0.7979397478679852

# %%
df['carat'].median()
# Out:
# 0.7

# %%
df['cut'].mode() # the most common value in the column
# Out:
# 0    Ideal
# Name: cut, dtype: object

# %% [markdown]
# ### Groupings

# %% [markdown]
# ![](https://i.imgur.com/Ij090Kn.jpg)
#
# Tables can also be grouped in order to view different characteristics of the dataset.
#
# For example, let's look at the average price of a diamond depending on the color.
#
# ```python
# df.groupby('col to group')['col of interest'].mean().sort_values()
# ```
# - `mean` - aggregating function, you can use another one
# - `sort_values` - sorting function

# %%
# using the groupby method
#df.groupby(by='color')

# select the column of interest
##df.group by(by='color')['price']

# choose what we want to count
##df.group by(by='color')['price'].mean()


df.groupby(by='color')['price'].mean()
# output pd.series
# Out:
# color
# D    3169.954096
# E    3076.752475
# F    3724.886397
# G    3999.135671
# H    4486.669196
# I    5091.874954
# J    5323.818020
# Name: price, dtype: float64

# %%
df.groupby('color')[['price']].mean()

# output pd.dataframe - look at the difference!
# Out:
#              price
# color
# D      3169.954096
# E      3076.752475
# F      3724.886397
# G      3999.135671
# H      4486.669196
# I      5091.874954
# J      5323.818020

# %%
# ['price','carat'] - list of column names
gr = df.groupby('color')[['price','carat']].mean()
gr
# Out:
#              price     carat
# color
# D      3169.954096  0.657795
# E      3076.752475  0.657867
# F      3724.886397  0.736538
# G      3999.135671  0.771190
# H      4486.669196  0.911799
# I      5091.874954  1.026927
# J      5323.818020  1.162137

# %%
# you can set the list separately
cols_to_use = ['price', 'carat']
gr = df.groupby('color')[cols_to_use].mean()
gr
# Out:
#              price     carat
# color
# D      3169.954096  0.657795
# E      3076.752475  0.657867
# F      3724.886397  0.736538
# G      3999.135671  0.771190
# H      4486.669196  0.911799
# I      5091.874954  1.026927
# J      5323.818020  1.162137

# %% [markdown]
# There are many ways to build simple graphs in pandas. More about them [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html ). More complicated ones are for later.
#
# Let's use the `.plot()` method and build a bar chart `(kind='bar')` of the average price of a diamond depending on the color.

# %%
df.groupby('color')['price'].mean().sort_values()
# Out:
# color
# E    3076.752475
# D    3169.954096
# F    3724.886397
# G    3999.135671
# H    4486.669196
# I    5091.874954
# J    5323.818020
# Name: price, dtype: float64

# %%
# bar graph
df.groupby('color')['price'].mean().sort_values().plot(kind='bar');

# %% [markdown]
# You can view several characteristics at once using the `.agg(['some_char_1','some_char_2'] method)` for multiple columns

# %%
df.groupby('color')[['price', 'carat']].agg(['mean','median'])
# Out:
#              price             carat
#               mean  median      mean median
# color
# D      3169.954096  1838.0  0.657795   0.53
# E      3076.752475  1739.0  0.657867   0.53
# F      3724.886397  2343.5  0.736538   0.70
# G      3999.135671  2242.0  0.771190   0.70
# H      4486.669196  3460.0  0.911799   0.90
# I      5091.874954  3730.0  1.026927   1.00
# J      5323.818020  4234.0  1.162137   1.11

# %%
df.groupby('weight')['price'].agg(['mean','median']).plot(kind='bar');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [115], in <cell line: 1>()
# ----> 1 df.groupby('weight')['price'].agg(['mean','median']).plot(kind='bar')
#
# File D:\Anaconda\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
#    7721     observed=observed,
#    7722     dropna=dropna,
#    7723 )
#
# File D:\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     879 if grouper is None:
#     880     from pandas.core.groupby.grouper import get_grouper
# --> 882     grouper, exclusions, obj = get_grouper(
#     883         obj,
#     884         keys,
#     885         axis=axis,
#     886         level=level,
#     887         sort=sort,
#     888         observed=observed,
#     889         mutated=self.mutated,
#     890         dropna=self.dropna,
#     891     )
#     893 self.obj = obj
#     894 self.axis = obj._get_axis_number(axis)
#
# File D:\Anaconda\lib\site-packages\pandas\core\groupby\grouper.py:882, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     880         in_axis, level, gpr = False, gpr, None
#     881     else:
# --> 882         raise KeyError(gpr)
#     883 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     884     # Add key to exclusions
#     885     exclusions.add(gpr.key)
#
# KeyError: 'weight'

# %% [markdown]
# ## ![title](https://i.imgur.com/6PannTm.jpg)
#
# You can build complex pivot tables.
#
# For example, you can look at the average price of a diamond depending on the color (color) and the quality of the cut (cut)

# %%
# columns='color' - what will be the columns in the pivot table
# index='cut' - what will be the rows in the pivot table
# values='price' - which column will we use to calculate something
# aggfunc='mean' - what will we consider

df.pivot_table(columns='color', index='cut', values='price', aggfunc='mean')\
    .style.background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_5ac3f_row0_col0 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_5ac3f_row0_col1, #T_5ac3f_row1_col0, #T_5ac3f_row2_col1, #T_5ac3f_row3_col1, #T_5ac3f_row4_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_5ac3f_row0_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_5ac3f_row0_col3 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_5ac3f_row0_col4, #T_5ac3f_row1_col5, #T_5ac3f_row2_col6, #T_5ac3f_row3_col6, #T_5ac3f_row4_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5ac3f_row0_col5 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_5ac3f_row0_col6 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_5ac3f_row1_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_5ac3f_row1_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_5ac3f_row1_col3 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_5ac3f_row1_col4 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_5ac3f_row1_col6 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_5ac3f_row2_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_5ac3f_row2_col2 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_5ac3f_row2_col3 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_5ac3f_row2_col4 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_5ac3f_row2_col5 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_5ac3f_row3_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_5ac3f_row3_col2 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_5ac3f_row3_col3 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_5ac3f_row3_col4 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_5ac3f_row3_col5 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_5ac3f_row4_col0 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_5ac3f_row4_col2 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_5ac3f_row4_col3 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_5ac3f_row4_col4 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_5ac3f_row4_col6 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5ac3f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >color</th>
#       <th id="T_5ac3f_level0_col0" class="col_heading level0 col0" >D</th>
#       <th id="T_5ac3f_level0_col1" class="col_heading level0 col1" >E</th>
#       <th id="T_5ac3f_level0_col2" class="col_heading level0 col2" >F</th>
#       <th id="T_5ac3f_level0_col3" class="col_heading level0 col3" >G</th>
#       <th id="T_5ac3f_level0_col4" class="col_heading level0 col4" >H</th>
#       <th id="T_5ac3f_level0_col5" class="col_heading level0 col5" >I</th>
#       <th id="T_5ac3f_level0_col6" class="col_heading level0 col6" >J</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ac3f_level0_row0" class="row_heading level0 row0" >Fair</th>
#       <td id="T_5ac3f_row0_col0" class="data row0 col0" >4291.061350</td>
#       <td id="T_5ac3f_row0_col1" class="data row0 col1" >3682.312500</td>
#       <td id="T_5ac3f_row0_col2" class="data row0 col2" >3827.003205</td>
#       <td id="T_5ac3f_row0_col3" class="data row0 col3" >4239.254777</td>
#       <td id="T_5ac3f_row0_col4" class="data row0 col4" >5135.683168</td>
#       <td id="T_5ac3f_row0_col5" class="data row0 col5" >4685.445714</td>
#       <td id="T_5ac3f_row0_col6" class="data row0 col6" >4975.655462</td>
#     </tr>
#     <tr>
#       <th id="T_5ac3f_level0_row1" class="row_heading level0 row1" >Good</th>
#       <td id="T_5ac3f_row1_col0" class="data row1 col0" >3405.382175</td>
#       <td id="T_5ac3f_row1_col1" class="data row1 col1" >3423.644159</td>
#       <td id="T_5ac3f_row1_col2" class="data row1 col2" >3495.750275</td>
#       <td id="T_5ac3f_row1_col3" class="data row1 col3" >4123.482204</td>
#       <td id="T_5ac3f_row1_col4" class="data row1 col4" >4276.254986</td>
#       <td id="T_5ac3f_row1_col5" class="data row1 col5" >5078.532567</td>
#       <td id="T_5ac3f_row1_col6" class="data row1 col6" >4574.172638</td>
#     </tr>
#     <tr>
#       <th id="T_5ac3f_level0_row2" class="row_heading level0 row2" >Ideal</th>
#       <td id="T_5ac3f_row2_col0" class="data row2 col0" >2629.094566</td>
#       <td id="T_5ac3f_row2_col1" class="data row2 col1" >2597.550090</td>
#       <td id="T_5ac3f_row2_col2" class="data row2 col2" >3374.939362</td>
#       <td id="T_5ac3f_row2_col3" class="data row2 col3" >3720.706388</td>
#       <td id="T_5ac3f_row2_col4" class="data row2 col4" >3889.334831</td>
#       <td id="T_5ac3f_row2_col5" class="data row2 col5" >4451.970377</td>
#       <td id="T_5ac3f_row2_col6" class="data row2 col6" >4918.186384</td>
#     </tr>
#     <tr>
#       <th id="T_5ac3f_level0_row3" class="row_heading level0 row3" >Premium</th>
#       <td id="T_5ac3f_row3_col0" class="data row3 col0" >3631.292576</td>
#       <td id="T_5ac3f_row3_col1" class="data row3 col1" >3538.914420</td>
#       <td id="T_5ac3f_row3_col2" class="data row3 col2" >4324.890176</td>
#       <td id="T_5ac3f_row3_col3" class="data row3 col3" >4500.742134</td>
#       <td id="T_5ac3f_row3_col4" class="data row3 col4" >5216.706780</td>
#       <td id="T_5ac3f_row3_col5" class="data row3 col5" >5946.180672</td>
#       <td id="T_5ac3f_row3_col6" class="data row3 col6" >6294.591584</td>
#     </tr>
#     <tr>
#       <th id="T_5ac3f_level0_row4" class="row_heading level0 row4" >Very Good</th>
#       <td id="T_5ac3f_row4_col0" class="data row4 col0" >3470.467284</td>
#       <td id="T_5ac3f_row4_col1" class="data row4 col1" >3214.652083</td>
#       <td id="T_5ac3f_row4_col2" class="data row4 col2" >3778.820240</td>
#       <td id="T_5ac3f_row4_col3" class="data row4 col3" >3872.753806</td>
#       <td id="T_5ac3f_row4_col4" class="data row4 col4" >4535.390351</td>
#       <td id="T_5ac3f_row4_col5" class="data row4 col5" >5255.879568</td>
#       <td id="T_5ac3f_row4_col6" class="data row4 col6" >5103.513274</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.pivot_table(columns='carat', index='color', values='price', aggfunc='max')\
    .style.background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_05351_row0_col0, #T_05351_row0_col1, #T_05351_row0_col2, #T_05351_row1_col0, #T_05351_row1_col1, #T_05351_row1_col2, #T_05351_row2_col0, #T_05351_row3_col3, #T_05351_row3_col4, #T_05351_row4_col3, #T_05351_row4_col4, #T_05351_row4_col5, #T_05351_row5_col3, #T_05351_row5_col9, #T_05351_row6_col3, #T_05351_row6_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_05351_row0_col3, #T_05351_row0_col4, #T_05351_row0_col5, #T_05351_row1_col3, #T_05351_row2_col3, #T_05351_row6_col10, #T_05351_row6_col12, #T_05351_row6_col13, #T_05351_row6_col14, #T_05351_row6_col16, #T_05351_row6_col17 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_05351_row0_col6, #T_05351_row0_col9, #T_05351_row1_col4, #T_05351_row1_col5, #T_05351_row5_col10, #T_05351_row5_col11, #T_05351_row5_col14 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_05351_row0_col7, #T_05351_row3_col10, #T_05351_row3_col12, #T_05351_row3_col13, #T_05351_row3_col17, #T_05351_row4_col10, #T_05351_row4_col11, #T_05351_row5_col15, #T_05351_row5_col16, #T_05351_row5_col18, #T_05351_row6_col18, #T_05351_row6_col22, #T_05351_row6_col24, #T_05351_row6_col29 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_05351_row0_col8, #T_05351_row1_col6, #T_05351_row1_col7, #T_05351_row1_col8, #T_05351_row1_col9, #T_05351_row2_col6, #T_05351_row2_col7, #T_05351_row2_col8, #T_05351_row3_col11, #T_05351_row4_col14, #T_05351_row4_col17, #T_05351_row5_col12, #T_05351_row5_col13, #T_05351_row5_col17 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_05351_row0_col10, #T_05351_row0_col14, #T_05351_row3_col24, #T_05351_row3_col36, #T_05351_row4_col41, #T_05351_row4_col42, #T_05351_row6_col52, #T_05351_row6_col56, #T_05351_row6_col59 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_05351_row0_col11, #T_05351_row0_col18, #T_05351_row0_col29, #T_05351_row1_col24, #T_05351_row1_col26, #T_05351_row2_col20, #T_05351_row2_col26, #T_05351_row2_col29, #T_05351_row4_col31, #T_05351_row4_col33, #T_05351_row5_col34, #T_05351_row5_col39, #T_05351_row5_col41, #T_05351_row5_col43, #T_05351_row5_col44, #T_05351_row5_col47, #T_05351_row6_col66, #T_05351_row6_col68 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_05351_row0_col12, #T_05351_row0_col13, #T_05351_row0_col19, #T_05351_row1_col14, #T_05351_row1_col15, #T_05351_row1_col17, #T_05351_row2_col16, #T_05351_row3_col15, #T_05351_row3_col21, #T_05351_row4_col23, #T_05351_row5_col20, #T_05351_row5_col22, #T_05351_row5_col23, #T_05351_row5_col24, #T_05351_row5_col26, #T_05351_row6_col20, #T_05351_row6_col26, #T_05351_row6_col30, #T_05351_row6_col33 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_05351_row0_col15, #T_05351_row0_col16, #T_05351_row2_col12, #T_05351_row2_col22, #T_05351_row3_col28, #T_05351_row3_col29, #T_05351_row4_col27, #T_05351_row4_col49, #T_05351_row5_col30, #T_05351_row5_col36, #T_05351_row5_col37, #T_05351_row5_col40, #T_05351_row5_col46, #T_05351_row6_col41 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_05351_row0_col17, #T_05351_row0_col20, #T_05351_row0_col23, #T_05351_row0_col25, #T_05351_row1_col21, #T_05351_row2_col9, #T_05351_row5_col38, #T_05351_row6_col34, #T_05351_row6_col44 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_05351_row0_col21, #T_05351_row2_col23, #T_05351_row4_col48, #T_05351_row5_col31, #T_05351_row6_col35 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_05351_row0_col22, #T_05351_row2_col21, #T_05351_row3_col27, #T_05351_row5_col33, #T_05351_row6_col37, #T_05351_row6_col43, #T_05351_row6_col47 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_05351_row0_col24, #T_05351_row0_col47, #T_05351_row1_col28, #T_05351_row1_col29, #T_05351_row3_col32, #T_05351_row3_col33, #T_05351_row3_col34, #T_05351_row4_col30, #T_05351_row4_col32, #T_05351_row4_col35, #T_05351_row4_col39, #T_05351_row4_col43, #T_05351_row4_col44, #T_05351_row4_col46, #T_05351_row5_col45, #T_05351_row6_col50 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_05351_row0_col26, #T_05351_row1_col27, #T_05351_row2_col14, #T_05351_row2_col27, #T_05351_row2_col28, #T_05351_row3_col30, #T_05351_row3_col31, #T_05351_row4_col38, #T_05351_row5_col42 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_05351_row0_col27, #T_05351_row2_col47, #T_05351_row6_col53, #T_05351_row6_col54, #T_05351_row6_col58, #T_05351_row6_col60, #T_05351_row6_col65 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_05351_row0_col28, #T_05351_row1_col35, #T_05351_row2_col36, #T_05351_row2_col39, #T_05351_row2_col46, #T_05351_row4_col64, #T_05351_row6_col51, #T_05351_row6_col61 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_05351_row0_col30, #T_05351_row1_col39, #T_05351_row4_col58, #T_05351_row5_col53, #T_05351_row5_col62, #T_05351_row5_col64 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_05351_row0_col31, #T_05351_row0_col35, #T_05351_row2_col42, #T_05351_row5_col56, #T_05351_row5_col65, #T_05351_row5_col66, #T_05351_row6_col72 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_05351_row0_col32, #T_05351_row0_col49, #T_05351_row1_col33, #T_05351_row1_col41, #T_05351_row1_col46, #T_05351_row2_col37, #T_05351_row2_col40, #T_05351_row2_col44, #T_05351_row2_col66, #T_05351_row3_col45, #T_05351_row4_col69, #T_05351_row5_col52, #T_05351_row5_col61, #T_05351_row6_col76 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_05351_row0_col33, #T_05351_row3_col51, #T_05351_row4_col51, #T_05351_row4_col56, #T_05351_row4_col57, #T_05351_row5_col75, #T_05351_row5_col78, #T_05351_row6_col70 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_05351_row0_col34, #T_05351_row0_col37, #T_05351_row0_col52, #T_05351_row1_col54, #T_05351_row5_col59, #T_05351_row6_col79, #T_05351_row6_col124 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_05351_row0_col36, #T_05351_row0_col55, #T_05351_row0_col62, #T_05351_row1_col66, #T_05351_row2_col63, #T_05351_row5_col71, #T_05351_row6_col83, #T_05351_row6_col88, #T_05351_row6_col90 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_05351_row0_col38, #T_05351_row2_col41, #T_05351_row2_col49, #T_05351_row3_col50, #T_05351_row3_col54, #T_05351_row3_col56, #T_05351_row3_col57 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_05351_row0_col39, #T_05351_row1_col52, #T_05351_row1_col55, #T_05351_row1_col58, #T_05351_row1_col77, #T_05351_row2_col50, #T_05351_row2_col62, #T_05351_row2_col78 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_05351_row0_col40, #T_05351_row0_col41, #T_05351_row0_col44, #T_05351_row0_col59, #T_05351_row0_col67, #T_05351_row0_col69, #T_05351_row1_col45, #T_05351_row2_col64, #T_05351_row3_col64, #T_05351_row3_col65, #T_05351_row3_col66, #T_05351_row4_col68, #T_05351_row5_col77, #T_05351_row6_col77 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_05351_row0_col42, #T_05351_row0_col68, #T_05351_row1_col69, #T_05351_row3_col53, #T_05351_row4_col61, #T_05351_row5_col73 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_05351_row0_col43, #T_05351_row2_col60, #T_05351_row3_col76, #T_05351_row4_col81, #T_05351_row4_col82, #T_05351_row5_col87, #T_05351_row5_col123, #T_05351_row6_col104, #T_05351_row6_col120 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_05351_row0_col45, #T_05351_row0_col66, #T_05351_row0_col73, #T_05351_row0_col77, #T_05351_row1_col56, #T_05351_row2_col52, #T_05351_row2_col68, #T_05351_row6_col81 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_05351_row0_col46, #T_05351_row0_col48, #T_05351_row0_col58, #T_05351_row1_col64, #T_05351_row1_col65, #T_05351_row2_col31, #T_05351_row2_col54, #T_05351_row4_col60 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_05351_row0_col50, #T_05351_row0_col76, #T_05351_row1_col68, #T_05351_row2_col176, #T_05351_row4_col165, #T_05351_row6_col91 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_05351_row0_col51, #T_05351_row1_col78, #T_05351_row2_col65, #T_05351_row3_col78, #T_05351_row4_col74, #T_05351_row6_col82 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_05351_row0_col53, #T_05351

# %% [markdown]
# ### Unique values

# %% [markdown]
# Let's see how often diamonds of different quality (`cut` column) are found in the dataset, using the `.value_counts()` method

# %%
df['cut']
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: object

# %%
df['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
# let's check the arguments
# ?pd.value_counts

# %%
df['cut'].value_counts(normalize=True)
# Out:
# Ideal        0.399537
# Premium      0.255673
# Very Good    0.223990
# Good         0.090953
# Fair         0.029848
# Name: cut, dtype: float64

# %%
df['cut'].value_counts().plot(kind='pie');

# %%
df['cut'].value_counts().plot(kind='bar');

# %% [markdown]
# You can simply view the unique categories in the column using the `.unique()` method

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %% [markdown]
# And just the number of unique categories (or values) can be viewed using the `.nunique()` method

# %%
df['cut'].nunique()
# Out:
# 5

# %% [markdown]
# ## Distribution histogram

# %%
df['price'].describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %%
df['price'].plot(kind='hist', bins=30);

# %%
import seaborn as sns
sns.histplot(data=df, x='price', bins=30);

# %% [markdown]
# ### Average, Median, Mode
#
# <img src='https://i.pinimg.com/originals/5e/70/90/5e70902088cb6036fa8954327c426aa4.png' width=300>

# %%
x = df['price'].sample(5).values
x = sorted(x)
x
# Out:
# [624, 3082, 8688, 12316, 18077]

# %%
np.mean(x)
# Out:
# 8557.4

# %%
np.median(x)
# Out:
# 8688.0

# %%
df['price'].mean(), df['price'].median(), df['price'].round(-2).mode()[0]
# Out:
# (3932.799721913237, 2401.0, 700)

# %% [markdown]
# ## Creating and deleting columns

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# Let's add a new diamond volume column to the table using the length, height and depth of the diamond

# %%
df['x']
# Out:
# 0        3.95
# 1        3.89
# 2        4.05
# 3        4.20
# 4        4.34
#          ...
# 53935    5.75
# 53936    5.69
# 53937    5.66
# 53938    6.15
# 53939    5.83
# Name: x, Length: 53940, dtype: float64

# %%
df['y']
# Out:
# 0        3.98
# 1        3.84
# 2        4.07
# 3        4.23
# 4        4.35
#          ...
# 53935    5.76
# 53936    5.75
# 53937    5.68
# 53938    6.12
# 53939    5.87
# Name: y, Length: 53940, dtype: float64

# %%
df['z']
# Out:
# 0        2.43
# 1        2.31
# 2        2.31
# 3        2.63
# 4        2.75
#          ...
# 53935    3.50
# 53936    3.61
# 53937    3.56
# 53938    3.74
# 53939    3.64
# Name: z, Length: 53940, dtype: float64

# %%
df['z'] * df['y']
# Out:
# 0         9.6714
# 1         8.8704
# 2         9.4017
# 3        11.1249
# 4        11.9625
#           ...
# 53935    20.1600
# 53936    20.7575
# 53937    20.2208
# 53938    22.8888
# 53939    21.3668
# Length: 53940, dtype: float64

# %%
df['volume'] = df['x'] * df['y'] * df['z']

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#       volume
# 0  38.202030
# 1  34.505856
# 2  38.076885
# 3  46.724580
# 4  51.917250

# %% [markdown]
# And we will remove columns with length, height and depth using the `.drop()` method
#
# - specify the columns to be deleted - the list of `drop_cols`
# - `axis=0` - means that we delete the lines
# - `axis=1` - means that we are deleting columns, not rows
# - `inplace=True` - means that we delete columns in the current dataset, and do not output a new one

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#       volume
# 0  38.202030
# 1  34.505856
# 2  38.076885
# 3  46.724580
# 4  51.917250

# %%
# without inplace, we will delete carat
df.drop(['x','y','z','table','depth'], axis=1)
# Out:
#        carat        cut color clarity  price      volume
# 0       0.23      Ideal     E     SI2    326   38.202030
# 1       0.21    Premium     E     SI1    326   34.505856
# 2       0.23       Good     E     VS1    327   38.076885
# 3       0.29    Premium     I     VS2    334   46.724580
# 4       0.31       Good     J     SI2    335   51.917250
# ...      ...        ...   ...     ...    ...         ...
# 53935   0.72      Ideal     D     SI1   2757  115.920000
# 53936   0.72       Good     D     SI1   2757  118.110175
# 53937   0.70  Very Good     D     SI1   2757  114.449728
# 53938   0.86    Premium     H     SI2   2757  140.766120
# 53939   0.75      Ideal     D     SI2   2757  124.568444
#
# [53940 rows x 6 columns]

# %%
# they stayed!
df.head(2)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
#
#       volume
# 0  38.202030
# 1  34.505856

# %%
drop_cols = ['x','y','z','table','depth']
df.drop(drop_cols, axis=1, inplace=True)

# or the same without inplace - the first method is better
# df = df.drop(drop_cols, axis=1)

# %%
df.head(25)
# Out:
#     carat        cut color clarity  price     volume
# 0    0.23      Ideal     E     SI2    326  38.202030
# 1    0.21    Premium     E     SI1    326  34.505856
# 2    0.23       Good     E     VS1    327  38.076885
# 3    0.29    Premium     I     VS2    334  46.724580
# 4    0.31       Good     J     SI2    335  51.917250
# 5    0.24  Very Good     J    VVS2    336  38.693952
# 6    0.24  Very Good     I    VVS1    336  38.830870
# 7    0.26  Very Good     H     SI1    337  42.321081
# 8    0.22       Fair     E     VS2    337  36.425214
# 9    0.23  Very Good     H     VS1    338  38.718000
# 10   0.30       Good     J     SI1    339  49.658700
# 11   0.23      Ideal     J     VS1    340  37.704420
# 12   0.22    Premium     F     SI1    342  34.715136
# 13   0.31      Ideal     J     SI2    344  51.515745
# 14   0.20    Premium     E     SI2    345  32.262375
# 15   0.32    Premium     E      I1    345  51.883728
# 16   0.30      Ideal     I     SI2    348  50.130472
# 17   0.30       Good     J     SI1    351  48.996090
# 18   0.30       Good     J     SI1    351  48.833658
# 19   0.30  Very Good     J     SI1    351  47.818022
# 20   0.30       Good     I     SI2    351  49.641780
# 21   0.23  Very Good     E     VS2    352  37.428160
# 22   0.23  Very Good     H     VS1    353  37.601784
# 23   0.31  Very Good     J     SI1    353  50.952974
# 24   0.31  Very Good     J     SI1    353  51.403212

# %% [markdown]
# We will also convert carats into milligrams (multiplying the mass in carats by 200)

# %%
# it is simply displayed on the screen
df['carat']*200
# Out:
# 0         46.0
# 1         42.0
# 2         46.0
# 3         58.0
# 4         62.0
#          ...
# 53935    144.0
# 53936    144.0
# 53937    140.0
# 53938    172.0
# 53939    150.0
# Name: carat, Length: 53940, dtype: float64

# %%
# we write it in the column
df['carat'] = df['carat']*200
df.head()
# Out:
#    carat      cut color clarity  price     volume
# 0   46.0    Ideal     E     SI2    326  38.202030
# 1   42.0  Premium     E     SI1    326  34.505856
# 2   46.0     Good     E     VS1    327  38.076885
# 3   58.0  Premium     I     VS2    334  46.724580
# 4   62.0     Good     J     SI2    335  51.917250

# %% [markdown]
# Rename the column

# %%
# we will pass the dictionary, where we will indicate what to change to what
# {'carat':'weight'} - dictionary with one key-value pair

df.rename(columns={'carat':'weight'}, inplace=True)

# %% [markdown]
# Let's look at the dataset now

# %%
# the name has changed
df.head()
# Out:
#    weight      cut color clarity  price     volume
# 0    46.0    Ideal     E     SI2    326  38.202030
# 1    42.0  Premium     E     SI1    326  34.505856
# 2    46.0     Good     E     VS1    327  38.076885
# 3    58.0  Premium     I     VS2    334  46.724580
# 4    62.0     Good     J     SI2    335  51.917250

# %% [markdown]
# To build a point graph of the price dependence on the mass, we use the `.plot()` method, specify its type `kind=` and the rest of the necessary arguments.

# %%
# s - the size of the dots
# x,y - what on which axes
df.plot(kind='scatter', x='weight', y='price', s=0.2);

# %%
# logarithm x and y
df.plot(kind='scatter', x='weight', y='price', s=0.2, loglog=True);

# %% [markdown]
# ## Indexing and slicing

# %% [markdown]
# ### Indexing

# %% [markdown]
# Let's figure out how to get certain rows and columns from the dataset
#
# - for indexing by row and column number, the `iloc[:, :]` attribute is used
# - row indexes are specified first, then columns
#
#
# - for indexing by row and column name, the `loc[:, :]` attribute is used
# - row names are specified first, then columns

# %%
idx = df.index.values
np.random.shuffle(idx)
df.index = idx

# %%
df.head()
# Out:
#        weight      cut color clarity  price     volume
# 14794    46.0    Ideal     E     SI2    326  38.202030
# 7150     42.0  Premium     E     SI1    326  34.505856
# 49714    46.0     Good     E     VS1    327  38.076885
# 1004     58.0  Premium     I     VS2    334  46.724580
# 15711    62.0     Good     J     SI2    335  51.917250

# %%
# indexes from 1 to 53940
df[:10]
# Out:
#        weight        cut color clarity  price     volume
# 14794    46.0      Ideal     E     SI2    326  38.202030
# 7150     42.0    Premium     E     SI1    326  34.505856
# 49714    46.0       Good     E     VS1    327  38.076885
# 1004     58.0    Premium     I     VS2    334  46.724580
# 15711    62.0       Good     J     SI2    335  51.917250
# 23190    48.0  Very Good     J    VVS2    336  38.693952
# 12293    48.0  Very Good     I    VVS1    336  38.830870
# 24392    52.0  Very Good     H     SI1    337  42.321081
# 29646    44.0       Fair     E     VS2    337  36.425214
# 41236    46.0  Very Good     H     VS1    338  38.718000

# %%
# you can also use slices
df.iloc[:3, 2:5]
# Out:
#       color clarity  price
# 14794     E     SI2    326
# 7150      E     SI1    326
# 49714     E     VS1    327

# %%
# indexes on the account 45 and 50 on the account from 0
df.iloc[[45,50]]
# Out:
#        weight        cut color clarity  price    volume
# 42711    58.0    Premium     F     SI1    403  47.86536
# 35334    48.0  Very Good     F     SI1    404  39.69147

# %%
# exactly 45 and 50 indexes
df.loc[[45,50]]
# Out:
#     weight        cut color clarity  price      volume
# 45   242.0  Very Good     J     VS2   4754  196.056056
# 50    60.0       Good     H     VS1    526   49.227750

# %%
# you can take part of the columns
df.loc[[45,50], ['weight','price']]
# Out:
#     weight  price
# 45   242.0   4754
# 50    60.0    526

# %% [markdown]
# ### Conditional slices

# %% [markdown]
# Instead of slices (for example, 45:50), you can use conditions.
#
# Consider an example. If we consider the descriptive statistics of the volume column, then it has zero values.

# %%
df[['weight','volume']].describe()
# Out:
#              weight        volume
# count  53940.000000  53940.000000
# mean     159.587950    129.849403
# std       94.802249     78.245262
# min       40.000000      0.000000
# 25%       80.000000     65.136830
# 50%      140.000000    114.808572
# 75%      208.000000    170.842451
# max     1002.000000   3840.598060

# %% [markdown]
# At the same time, if we consider the mass and volume of diamonds with a zero volume value, then the mass of such diamonds in most cases turns out to be significantly higher than average, so it is unlikely that their real volume is zero.

# %%
# comparing each row with zero
df['volume'] == 0
# Out:
# 14794    False
# 7150     False
# 49714    False
# 1004     False
# 15711    False
#          ...
# 16264    False
# 1655     False
# 9869     False
# 37761    False
# 31817    False
# Name: volume, Length: 53940, dtype: bool

# %%
sum(df['volume'] == 0)
# Out:
# 20

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
# we leave only those lines where the volume is zero
df[df['volume'] == 0]
# Out:
#        weight        cut color clarity  price  volume
# 51054   200.0    Premium     G     SI2   3142     0.0
# 30299   202.0    Premium     H      I1   3167     0.0
# 53348   220.0    Premium     G     SI2   3696     0.0
# 44562   202.0    Premium     F     SI2   3837     0.0
# 33171   300.0       Good     G      I1   4731     0.0
# 34657   214.0      Ideal     F     SI2   4954     0.0
# 2261    200.0  Very Good     H     VS2   5139     0.0
# 23685   230.0      Ideal     G     VS2   5564     0.0
# 14146   228.0       Fair     G     VS1   6381     0.0
# 50421   436.0    Premium     H     SI2  12631     0.0
# 45545   312.0      Ideal     G     VS2  12800     0.0
# 40840   450.0    Premium     I     SI1  15397     0.0
# 4576    240.0    Premium     D    VVS1  15686     0.0
# 17086   440.0    Premium     H     SI1  17265     0.0
# 14737   450.0    Premium     H     SI2  18034     0.0
# 52116   404.0    Premium     H     VS2  18207     0.0
# 4003    560.0       Good     G     SI2  18788     0.0
# 50500   142.0       Good     F     SI2   2130     0.0
# 50181   142.0       Good     F     SI2   2130     0.0
# 11562   224.0    Premium     G      I1   2383     0.0

# %%
df.query('volume == 0')
# Out:
#        weight        cut color clarity  price  volume
# 51054   200.0    Premium     G     SI2   3142     0.0
# 30299   202.0    Premium     H      I1   3167     0.0
# 53348   220.0    Premium     G     SI2   3696     0.0
# 44562   202.0    Premium     F     SI2   3837     0.0
# 33171   300.0       Good     G      I1   4731     0.0
# 34657   214.0      Ideal     F     SI2   4954     0.0
# 2261    200.0  Very Good     H     VS2   5139     0.0
# 23685   230.0      Ideal     G     VS2   5564     0.0
# 14146   228.0       Fair     G     VS1   6381     0.0
# 50421   436.0    Premium     H     SI2  12631     0.0
# 45545   312.0      Ideal     G     VS2  12800     0.0
# 40840   450.0    Premium     I     SI1  15397     0.0
# 4576    240.0    Premium     D    VVS1  15686     0.0
# 17086   440.0    Premium     H     SI1  17265     0.0
# 14737   450.0    Premium     H     SI2  18034     0.0
# 52116   404.0    Premium     H     VS2  18207     0.0
# 4003    560.0       Good     G     SI2  18788     0.0
# 50500   142.0       Good     F     SI2   2130     0.0
# 50181   142.0       Good     F     SI2   2130     0.0
# 11562   224.0    Premium     G      I1   2383     0.0

# %% [markdown]
# We will leave only lines with non-zero volume in the dataset

# %%
# shape before
df.shape
# Out:
# (53940, 6)

# %%
df = df[df['volume']>0]

# %%
# shape now
df.shape
# Out:
# (53920, 6)

# %%
# how many diamonds have price higher than the average value?
df[df['price'] > df['price'].mean()].shape[0]
# Out:
# 19657

# %%
df.shape[0]
# Out:
# 53920

# %%
19657 / 53920
# Out:
# 0.3645586053412463

# %% [markdown]
# ### Conditional operators

# %% [markdown]
# You can also make slices from a table using multiple conditions using operators
# - `|` (or)
# - `&` (and)
#
# ```python
# df[(`condition_1`) | (`condition_2`)]
# ```

# %%
True or False # any
# Out:
# True

# %%
True and False # all
# Out:
# False

# %%
df[(df['volume'] >= 100) & (df['volume'] <= 200)]
# Out:
#        weight        cut color clarity  price      volume
# 22821   140.0      Ideal     E     SI1   2757  116.396280
# 46937   172.0       Fair     E     SI2   2757  143.716320
# 41330   140.0      Ideal     G     VS2   2757  113.116500
# 13151   142.0  Very Good     E     VS2   2759  115.865184
# 35197   156.0  Very Good     G     SI2   2759  126.437220
# ...       ...        ...   ...     ...    ...         ...
# 16264   144.0      Ideal     D     SI1   2757  115.920000
# 1655    144.0       Good     D     SI1   2757  118.110175
# 9869    140.0  Very Good     D     SI1   2757  114.449728
# 37761   172.0    Premium     H     SI2   2757  140.766120
# 31817   150.0      Ideal     D     SI2   2757  124.568444
#
# [21024 rows x 6 columns]

# %%
# the same thing in steps and without extra brackets
over100 = df['volume'] >= 100
under200 = df['volume'] <= 200
condition = over100 & under200

df[condition].describe()
# Out:
#              weight         price        volume
# count  21024.000000  21024.000000  21024.000000
# mean     185.104357   4447.483019    150.260471
# std       33.920223   2072.115478     27.350647
# min       70.000000    468.000000    100.001446
# 25%      148.000000   2863.000000    120.880244
# 50%      200.000000   4118.000000    156.358128
# 75%      208.000000   5395.000000    170.158740
# max      412.000000  18542.000000    199.999475

# %% [markdown]
# Let's look at all the perfect and premium diamonds

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
condition_1 = df['cut']=='Ideal'
condition_2 = df['cut']=='Premium'
df[condition_1 | condition_2]
# Out:
#        weight      cut color clarity  price      volume
# 14794    46.0    Ideal     E     SI2    326   38.202030
# 7150     42.0  Premium     E     SI1    326   34.505856
# 1004     58.0  Premium     I     VS2    334   46.724580
# 28009    46.0    Ideal     J     VS1    340   37.704420
# 10476    44.0  Premium     F     SI1    342   34.715136
# ...       ...      ...   ...     ...    ...         ...
# 41373   142.0  Premium     F     SI1   2756  112.813386
# 28964   144.0  Premium     D     SI1   2757  116.721246
# 16264   144.0    Ideal     D     SI1   2757  115.920000
# 37761   172.0  Premium     H     SI2   2757  140.766120
# 31817   150.0    Ideal     D     SI2   2757  124.568444
#
# [35328 rows x 6 columns]

# %% [markdown]
# Let's look at all the perfect diamonds weighing more than 500 milligrams

# %%
df[(df['cut']=='Ideal') & (df['weight']>500)]
# Out:
#        weight    cut color clarity  price      volume
# 13126   544.0  Ideal     H      I1  11594  456.285445
# 26036   644.0  Ideal     I      I1  12545  529.223136
# 15567   700.0  Ideal     H      I1  12587  558.037305
# 12234   508.0  Ideal     I     SI2  12687  419.423234
# 11989   550.0  Ideal     D      I1  13156  445.673808
# 53856   508.0  Ideal     G     SI2  14421  414.404375
# 15420   502.0  Ideal     H     SI1  15324  404.407395
# 5526    506.0  Ideal     J     SI2  15993  413.613508
# 33477   602.0  Ideal     J     SI2  16037  484.219000
# 15596   518.0  Ideal     J     VS1  16465  420.494313
# 43677   602.0  Ideal     J      I1  16538  470.444902
# 29292   506.0  Ideal     I     SI1  16709  401.884868
# 46459   526.0  Ideal     J     SI2  16914  431.257200
# 37736   502.0  Ideal     H     SI2  17162  407.496936
# 27563   522.0  Ideal     J     SI2  17209  409.521735
# 6133    504.0  Ideal     I     SI1  17231  408.788028
# 321     508.0  Ideal     G     SI2  17339  414.209250
# 4497    528.0  Ideal     H     SI2  17407  432.825408
# 1533    512.0  Ideal     J     SI1  17753  410.669676
# 12316   544.0  Ideal     J     SI2  17801  445.367676
# 38226   502.0  Ideal     I     SI2  18037  401.531595
# 48358   520.0  Ideal     J     SI2  18369  423.694044
# 51148   522.0  Ideal     I     SI2  18756  421.842330

# %% [markdown]
# ### Working with strings

# %% [markdown]
# To work with string columns, you can also use the following methods
#
# - `.isin()` – in order to leave only those lines whose categories are in some list
#
# ```python
# df['col'].isin(['category1', 'category2'])
# ```
#
# - `.str()` – in order to use the methods that strings
# have - `.str.contains()` – in order to leave strings whose contents have a specific text
#
# ```python
# df['col'].str.contains(['some_text'])
# ```

# %%
# rows with logical variables again
cut_interested = ['Ideal', 'Premium']
df[df['cut'].isin(cut_interested)]
# Out:
#        weight      cut color clarity  price      volume
# 14794    46.0    Ideal     E     SI2    326   38.202030
# 7150     42.0  Premium     E     SI1    326   34.505856
# 1004     58.0  Premium     I     VS2    334   46.724580
# 28009    46.0    Ideal     J     VS1    340   37.704420
# 10476    44.0  Premium     F     SI1    342   34.715136
# ...       ...      ...   ...     ...    ...         ...
# 41373   142.0  Premium     F     SI1   2756  112.813386
# 28964   144.0  Premium     D     SI1   2757  116.721246
# 16264   144.0    Ideal     D     SI1   2757  115.920000
# 37761   172.0  Premium     H     SI2   2757  140.766120
# 31817   150.0    Ideal     D     SI2   2757  124.568444
#
# [35328 rows x 6 columns]

# %%
# making a conditional slice
df[df['cut'].isin(['Ideal', 'Premium'])]
# Out:
#        weight      cut color clarity  price      volume
# 14794    46.0    Ideal     E     SI2    326   38.202030
# 7150     42.0  Premium     E     SI1    326   34.505856
# 1004     58.0  Premium     I     VS2    334   46.724580
# 28009    46.0    Ideal     J     VS1    340   37.704420
# 10476    44.0  Premium     F     SI1    342   34.715136
# ...       ...      ...   ...     ...    ...         ...
# 41373   142.0  Premium     F     SI1   2756  112.813386
# 28964   144.0  Premium     D     SI1   2757  116.721246
# 16264   144.0    Ideal     D     SI1   2757  115.920000
# 37761   172.0  Premium     H     SI2   2757  140.766120
# 31817   150.0    Ideal     D     SI2   2757  124.568444
#
# [35328 rows x 6 columns]

# %%
df['cut'].str.upper()
# Out:
# 14794        IDEAL
# 7150       PREMIUM
# 49714         GOOD
# 1004       PREMIUM
# 15711         GOOD
#            ...
# 16264        IDEAL
# 1655          GOOD
# 9869     VERY GOOD
# 37761      PREMIUM
# 31817        IDEAL
# Name: cut, Length: 53920, dtype: object

# %%
df[df['cut'].str.contains('Good')]
# Out:
#        weight        cut color clarity  price      volume
# 49714    46.0       Good     E     VS1    327   38.076885
# 15711    62.0       Good     J     SI2    335   51.917250
# 23190    48.0  Very Good     J    VVS2    336   38.693952
# 12293    48.0  Very Good     I    VVS1    336   38.830870
# 24392    52.0  Very Good     H     SI1    337   42.321081
# ...       ...        ...   ...     ...    ...         ...
# 40624   158.0       Good     F     SI1   2756  131.503212
# 41997   140.0  Very Good     E     VS2   2757  114.126912
# 20536   140.0  Very Good     E     VS2   2757  113.588332
# 1655    144.0       Good     D     SI1   2757  118.110175
# 9869    140.0  Very Good     D     SI1   2757  114.449728
#
# [16983 rows x 6 columns]

# %% [markdown]
# # Review
#
# Today we learned:
# - upload data
#     - `df = pd.read_csv('some_data.csv')`
# - look at them
#     - `df.head()`,`df.tail()`,
#     - `df.shape`, `df.info()`, `df.dtypes()`
# - calculate various characteristics
#     - `df.describe()`
#     - `df['col'].mean()`, `df['col'].median()`
# - make groupings
#     - `df.groupby('col1')['col2'].agg(['mean','median'])`
#     - `df.pivot_table(columns='col1', index='col2', values='col3', aggfunc='mean')`
# - count unique values
#     - `df['col'].value_counts(normalize=True)`, `df['col'].unique()` `df['col'].nunique()`
# - even build some graphics
#     - `df['col'].value_counts(normalize=True).plot(kind='bar')`
# - delete and rename columns
#     - `df.drop(['col1', 'col2'], axis=1, inplace=True)`
#     - `df.rename(columns={'old_col_name':'new_col_name'}, inplace=True)`
# - filter rows using complex conditions
#     - `df.loc[df['col']==some_value, ['col1', 'col2']]`
#     - `df[(df['col1']==some_value) | (df['col2']!=some_value)]`
#     - `df[(df['col1']>some_value) & (df['col2']<some_value)]`
#     - `df['col'].isin(['category1', 'category2'])`
#     - `df['col'].str.contains(['some_text'])`

# %% [markdown]
# # Practice

# %% [markdown]
# Solving following problems, try to use different methods

# %% [markdown]
# What quality diamonds (`cut` column) have the highest median price value?
#
# `Fair`

# %%
df.groupby('cut')['price'].median().sort_values(ascending=False) \
.index[0]
# Out:
# 'Fair'

# %% [markdown]
# What is the most common color of a diamond (`color`)?
#
# `G`

# %%
df['color'].value_counts().index[0]
# Out:
# 'G'

# %% [markdown]
# What is the most common diamond color among those whose price value is higher than the median?
#
# `G`

# %%
df['color'].mode().index[0]
# Out:
# 0

# %% [markdown]
# What is the most common quality of a diamond (`cut`) among those whose price value is higher than the median, and the weight is higher than the average?
#
# `Premium`

# %% [markdown]
# What is the average price of a diamond (price) among Premium and Ideal quality diamonds (cut)?
#
# `3894.8`

# %%
df[df['cut'].isin(['Premium', 'Ideal'])] \
['price'].mean()
# Out:
# 3897.204034859374
